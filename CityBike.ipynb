# %%
import pandas as pd

# %%
Jun_df = pd.read_csv('201906-citibike-tripdata.csv')
Jul_df = pd.read_csv('201907-citibike-tripdata.csv')
Aug_df = pd.read_csv('201908-citibike-tripdata.csv')
Sep_df = pd.read_csv('201909-citibike-tripdata.csv')
Oct_df = pd.read_csv('201910-citibike-tripdata.csv')
Nov_df = pd.read_csv('201911-citibike-tripdata.csv')
Dec_df = pd.read_csv('201912-citibike-tripdata.csv')

# %%
Jun_df.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
Jun_df.tail(1)
# Out:
#          tripduration                 starttime                  stoptime  \
# 2125369          1270  2019-06-30 23:59:54.3670  2019-07-01 00:21:05.2750
#
#          start station id start station name  start station latitude  \
# 2125369              3788     E 12 St & 4 Av                40.73269
#
#          start station longitude  end station id end station name  \
# 2125369                -73.98974             326  E 11 St & 1 Ave
#
#          end station latitude  end station longitude  bikeid    usertype  \
# 2125369             40.729538             -73.984267   38742  Subscriber
#
#          birth year  gender
# 2125369        1967       1

# %%
Jul_df.tail(1)
# Out:
#          tripduration                 starttime                  stoptime  \
# 2181063           274  2019-07-31 23:59:57.4870  2019-08-01 00:04:32.2070
#
#          start station id start station name  start station latitude  \
# 2181063            3459.0    E 53 St & 3 Ave               40.757632
#
#          start station longitude  end station id end station name  \
# 2181063               -73.969306          3134.0  3 Ave & E 62 St
#
#          end station latitude  end station longitude  bikeid    usertype  \
# 2181063             40.763126             -73.965269   25344  Subscriber
#
#          birth year  gender
# 2181063        1994       2

# %%
Aug_df.tail(1)
# Out:
#          tripduration                 starttime                  stoptime  \
# 2344223           419  2019-08-31 23:59:59.4520  2019-09-01 00:06:59.0210
#
#          start station id start station name  start station latitude  \
# 2344223             447.0    8 Ave & W 52 St               40.763707
#
#          start station longitude  end station id end station name  \
# 2344223               -73.985162           529.0  W 42 St & 8 Ave
#
#          end station latitude  end station longitude  bikeid    usertype  \
# 2344223              40.75757             -73.990985   35210  Subscriber
#
#          birth year  gender
# 2344223        1994       1

# %%
Sep_df.tail(1)
# Out:
#          tripduration                 starttime                  stoptime  \
# 2444899          1500  2019-09-30 23:59:55.3740  2019-10-01 00:24:55.8400
#
#          start station id   start station name  start station latitude  \
# 2444899               331  Pike St & Monroe St               40.711731
#
#          start station longitude  end station id end station name  \
# 2444899                -73.99193            2012  E 27 St & 1 Ave
#
#          end station latitude  end station longitude  bikeid  usertype  \
# 2444899             40.739445             -73.976806   34013  Customer
#
#          birth year  gender
# 2444899        1969       0

# %%
Oct_df.tail(1)
# Out:
#          tripduration                 starttime                  stoptime  \
# 2092572            81  2019-10-31 23:59:51.5170  2019-11-01 00:01:13.2150
#
#          start station id              start station name  \
# 2092572               539  Metropolitan Ave & Bedford Ave
#
#          start station latitude  start station longitude  end station id  \
# 2092572               40.715348               -73.960241            3093
#
#              end station name  end station latitude  end station longitude  \
# 2092572  N 6 St & Bedford Ave             40.717452             -73.958509
#
#          bikeid    usertype  birth year  gender
# 2092572   25745  Subscriber        1990       1

# %%
Nov_df.tail(1)
# Out:
#          tripduration                 starttime                  stoptime  \
# 1478707           811  2019-11-30 23:59:50.4100  2019-12-01 00:13:22.3840
#
#          start station id start station name  start station latitude  \
# 1478707               489   10 Ave & W 28 St               40.750664
#
#          start station longitude  end station id  \
# 1478707               -74.001768             358
#
#                       end station name  end station latitude  \
# 1478707  Christopher St & Greenwich St             40.732916
#
#          end station longitude  bikeid  usertype  birth year  gender
# 1478707             -74.007114   30502  Customer        1969       0

# %%
Dec_df.tail(1)
# Out:
#         tripduration                 starttime                  stoptime  \
# 955209           310  2019-12-31 23:59:55.2960  2020-01-01 00:05:05.7270
#
#         start station id start station name  start station latitude  \
# 955209              3351   E 102 St & 1 Ave               40.786995
#
#         start station longitude  end station id          end station name  \
# 955209               -73.941648            3379  E 103 St & Lexington Ave
#
#         end station latitude  end station longitude  bikeid    usertype  \
# 955209             40.790305             -73.947558   21013  Subscriber
#
#         birth year  gender
# 955209        1969       0

# %%
CityBike2019=pd.concat([Jun_df, Jul_df, Aug_df, Sep_df, Oct_df, Nov_df, Dec_df])

# %%
CityBike2019.tail(2)
# Out:
#         tripduration                 starttime                  stoptime  \
# 955208          1571  2019-12-31 23:59:21.3610  2020-01-01 00:25:32.9420
# 955209           310  2019-12-31 23:59:55.2960  2020-01-01 00:05:05.7270
#
#         start station id            start station name  \
# 955208             252.0  MacDougal St & Washington Sq
# 955209            3351.0              E 102 St & 1 Ave
#
#         start station latitude  start station longitude  end station id  \
# 955208               40.732264               -73.998522           366.0
# 955209               40.786995               -73.941648          3379.0
#
#                 end station name  end station latitude  end station longitude  \
# 955208  Clinton Ave & Myrtle Ave             40.693261             -73.968896
# 955209  E 103 St & Lexington Ave             40.790305             -73.947558
#
#         bikeid    usertype  birth year  gender
# 955208   28506  Subscriber        1980       1
# ...

# %%
CityBike2019['gender'] = CityBike2019['gender'].replace([0,1,2],['Unknown',"Male","Female"])

CityBike2019.tail(2)
# Out:
#         tripduration                 starttime                  stoptime  \
# 955208          1571  2019-12-31 23:59:21.3610  2020-01-01 00:25:32.9420
# 955209           310  2019-12-31 23:59:55.2960  2020-01-01 00:05:05.7270
#
#         start station id            start station name  \
# 955208             252.0  MacDougal St & Washington Sq
# 955209            3351.0              E 102 St & 1 Ave
#
#         start station latitude  start station longitude  end station id  \
# 955208               40.732264               -73.998522           366.0
# 955209               40.786995               -73.941648          3379.0
#
#                 end station name  end station latitude  end station longitude  \
# 955208  Clinton Ave & Myrtle Ave             40.693261             -73.968896
# 955209  E 103 St & Lexington Ave             40.790305             -73.947558
#
#         bikeid    usertype  birth year   gender
# 955208   28506  Subscriber        1980     Male
# ...

# %%
CityBike2019 = CityBike2019.dropna(how='any',axis=0)

# %%
CityBike2019.isnull().any()
# Out:
# tripduration               False
# starttime                  False
# stoptime                   False
# start station id           False
# start station name         False
# start station latitude     False
# start station longitude    False
# end station id             False
# end station name           False
# end station latitude       False
# end station longitude      False
# bikeid                     False
# usertype                   False
# birth year                 False
# gender                     False
# dtype: bool

# %%
CityBike2019.to_csv('citibike.csv', index=False)
